# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
shooting_data = pd.read_csv('../data/shooting_stats.csv')
advanced_data = pd.read_csv('../data/player_advanced_2020.csv')
raptor_data = pd.read_csv('../data/latest_RAPTOR_by_team.csv')

# %%
shooting_data.drop(columns=['Unnamed: 0','Rank','3-Pt Field Goals.3','3-Pt Field Goals.4'],inplace=True)

# %%
shooting_data.dropna(inplace=True)

# %%
shooting_data.reset_index(drop="index",inplace=True)

# %%
shooting_data.head()
# Out:
#    player_id                     Name Age games min_played   FG%  \
# 0  vanvlfr01  Fred VanVleet\vanvlfr01  25    47       1682  .410
# 1  anunoog01     OG Anunoby\anunoog01  22    56       1640  .499
# 2  lowryky01     Kyle Lowry\lowryky01  33    45       1635  .420
# 3  siakapa01  Pascal Siakam\siakapa01  25    46       1607  .464
# 4  ibakase01    Serge Ibaka\ibakase01  30    46       1246  .528
#
#   Avg_shot_dist %_2point_attempts %_FGA_0-3_dist %_FGA_3-10_dist  \
# 0          15.3              .521           .316            .105
# 1          11.7              .593           .453            .109
# 2          18.1              .431           .211            .098
# 3          12.2              .690           .298            .229
# 4          12.1              .751           .253            .261
#
#   %_FGA_10-16_dist %_FGA_16-3pt_dist %_3point_attempts %FG_2point  \
# 0             .039              .061              .479       .430
# ...

# %%
test = shooting_data['Name'][0]

# %%
test.split('\\')[1]
# Out:
# 'vanvlfr01'

# %%
player_id_lst = []
for i in shooting_data['Name']:  
    player_id_lst.append(i.split('\\')[1])

# %%
shooting_data['player_id'] = player_id_lst

# %%
id = shooting_data['player_id']
shooting_data.drop(labels=['player_id'], axis=1,inplace = True)
shooting_data.insert(0, 'player_id', id)
shooting_data
# Out:
#      player_id                                Name Age games min_played   FG%  \
# 0    vanvlfr01             Fred VanVleet\vanvlfr01  25    47       1682  .410
# 1    anunoog01                OG Anunoby\anunoog01  22    56       1640  .499
# 2    lowryky01                Kyle Lowry\lowryky01  33    45       1635  .420
# 3    siakapa01             Pascal Siakam\siakapa01  25    46       1607  .464
# 4    ibakase01               Serge Ibaka\ibakase01  30    46       1246  .528
# ..         ...                                 ...  ..   ...        ...   ...
# 377  mooreet01             E'Twaun Moore\mooreet01  30    44        861  .426
# 378  willike04          Kenrich Williams\willike04  25    35        779  .343
# 379  mellini01              Nicolò Melli\mellini01  29    45        722  .464
# 380  jacksfr01             Frank Jackson\jacksfr01  21    45        583  .404
# 381  alexani01  Nickeil Alexander-Walker\alexani01  21    41        501  .339
#
# ...

# %%
df3 = shooting_data.merge(raptor_data, how = 'left', on='player_id')

# %%
df3.head()
# Out:
#    player_id                     Name Age games min_played   FG%  \
# 0  vanvlfr01  Fred VanVleet\vanvlfr01  25    47       1682  .410
# 1  anunoog01     OG Anunoby\anunoog01  22    56       1640  .499
# 2  lowryky01     Kyle Lowry\lowryky01  33    45       1635  .420
# 3  siakapa01  Pascal Siakam\siakapa01  25    46       1607  .464
# 4  ibakase01    Serge Ibaka\ibakase01  30    46       1246  .528
#
#   Avg_shot_dist %_2point_attempts %_FGA_0-3_dist %_FGA_3-10_dist  \
# 0          15.3              .521           .316            .105
# 1          11.7              .593           .453            .109
# 2          18.1              .431           .211            .098
# 3          12.2              .690           .298            .229
# 4          12.1              .751           .253            .261
#
#   %_FGA_10-16_dist %_FGA_16-3pt_dist %_3point_attempts %FG_2point  \
# 0             .039              .061              .479       .430
# ...

# %%
df4 = advanced_data.merge(df3, how = 'inner', on='player_id')

# %%
df4.columns
# Out:
# Index(['player_id', 'Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age_x', 'Tm', 'G',
#        'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
#        'STL%', 'BLK%', 'TOV%', 'USG%', 'Unnamed: 19', 'OWS', 'DWS', 'WS',
#        'WS/48', 'Unnamed: 24', 'OBPM', 'DBPM', 'BPM', 'VORP', 'Name', 'Age_y',
#        'games', 'min_played', 'FG%', 'Avg_shot_dist', '%_2point_attempts',
#        '%_FGA_0-3_dist', '%_FGA_3-10_dist', '%_FGA_10-16_dist',
#        '%_FGA_16-3pt_dist', '%_3point_attempts', '%FG_2point', '%_FG_0-3_dist',
#        '%_FG_3-10_dist', '%_FG_10-16_dist', '%_FG_10-16_dist.1', '3pt%',
#        'assisted_2pters', 'FG%_dunk_attempts', 'made_dunks', 'assisted_3pt%',
#        '%_corner_3pters', '%_corner_3_made', 'player_name', 'season',
#        'season_type', 'team', 'poss', 'mp', 'raptor_box_offense',
#        'raptor_box_defense', 'raptor_box_total', 'raptor_onoff_offense',
#        'raptor_onoff_defense', 'raptor_onoff_total', 'raptor_offense',
# ...

# %%
df4.head()
# Out:
#    player_id  Unnamed: 0  Rk                              Player Pos  Age_x  \
# 0  adebaba01           1   2               Bam Adebayo\adebaba01  PF     22
# 1  aldrila01           2   3         LaMarcus Aldridge\aldrila01   C     34
# 2  alexani01           3   4  Nickeil Alexander-Walker\alexani01  SG     21
# 3  allengr01           4   5             Grayson Allen\allengr01  SG     24
# 4  allenka01           6   7              Kadeem Allen\allenka01  SG     27
#
#     Tm   G    MP   PER    TS%   3PAr    FTr  ORB%  DRB%  TRB%  AST%  STL%  \
# 0  MIA  54  1865  20.7  0.613  0.019  0.473   8.8  24.2  16.8  22.5   1.8
# 1  SAS  50  1661  20.3  0.580  0.195  0.245   6.4  18.1  12.2  11.3   0.9
# 2  NOP  41   501   7.7  0.441  0.515  0.123   1.7  15.3   8.4  20.5   1.0
# 3  MEM  30   498  11.4  0.577  0.517  0.199   1.1  12.7   7.0  11.7   0.6
# 4  NYK  10   117  14.1  0.512  0.364  0.250   1.7   6.6   4.1  27.4   2.1
#
# ...

# %%
df4.drop(columns=['Unnamed: 0','Rk','Player','Pos','Age_x','Tm','TS%','3PAr','Unnamed: 19','Unnamed: 24','OBPM','DBPM','BPM','VORP','Name','war_playoffs',],inplace=True)

# %%
df4.drop(columns=['G','PER','games','min_played','mp'],inplace=True)

# %%
df4.drop(columns=['season_type','poss'],inplace=True)

# %%
df4 = df4[df4['MP'] >250]

# %%
df4
# Out:
#      player_id    MP    FTr  ORB%  DRB%  TRB%  AST%  STL%  BLK%  TOV%  USG%  \
# 0    adebaba01  1865  0.473   8.8  24.2  16.8  22.5   1.8   3.4  17.2  19.9
# 1    aldrila01  1661  0.245   6.4  18.1  12.2  11.3   0.9   4.3   7.9  23.3
# 2    alexani01   501  0.123   1.7  15.3   8.4  20.5   1.0   1.2  14.3  22.9
# 3    allengr01   498  0.199   1.1  12.7   7.0  11.7   0.6   0.2  10.7  18.0
# 5    anderky01   868  0.254   5.6  18.4  12.1  15.4   1.9   2.4  14.8  13.4
# ..         ...   ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 608   woodch01  1013  0.508   8.6  25.3  16.9   6.9   1.2   3.7  11.9  21.9
# 609  wrighde01  1116  0.252   5.5  13.4   9.5  22.0   2.4   1.4  12.4  15.2
# 610  youngth01  1296  0.120   6.1  15.8  10.8  11.0   2.4   1.2  14.4  19.7
# 611  youngtr01  1760  0.444   1.8  11.8   6.7  45.9   1.5   0.2  16.4  35.0
# 612  zelleco01  1154  0.340  12.7  21.1  16.7  10.8   1.4   1.8  11.6  20.9
#
# ...

# %%
age = df4['Age_y']
df4.drop(labels=['Age_y'], axis=1,inplace = True)
df4.insert(2, 'age', age)
df4
# Out:
#                          name  player_id age  season team    MP    FTr  ORB%  \
# 0                 Bam Adebayo  adebaba01  22    2020  MIA  1865  0.473   8.8
# 1           LaMarcus Aldridge  aldrila01  34    2020  SAS  1661  0.245   6.4
# 2    Nickeil Alexander-Walker  alexani01  21    2020  NOP   501  0.123   1.7
# 3               Grayson Allen  allengr01  24    2020  MEM   498  0.199   1.1
# 5               Kyle Anderson  anderky01  26    2020  MEM   868  0.254   5.6
# ..                        ...        ...  ..     ...  ...   ...    ...   ...
# 608            Christian Wood   woodch01  24    2020  DET  1013  0.508   8.6
# 609              Delon Wright  wrighde01  27    2020  DAL  1116  0.252   5.5
# 610            Thaddeus Young  youngth01  31    2020  CHI  1296  0.120   6.1
# 611                Trae Young  youngtr01  21    2020  ATL  1760  0.444   1.8
# 612               Cody Zeller  zelleco01  27    2020  CHA  1154  0.340  12.7
#
# ...

# %%
df4.to_csv('/Users/brandonmojica/Desktop/Galvanize/Capstones/Capstone_3/nba_postion_classification/data/final_nba.csv')

# %%
pwd
# Out:
# '/Users/brandonmojica/Desktop/Galvanize/Capstones/Capstone_3/nba_postion_classification/notebooks'

# %%
adv_player_id_lst = []
for i in advanced_data['Player']:  
    adv_player_id_lst.append(i.split('\\')[1])

# %%
advanced_data['player_id'] = adv_player_id_lst

# %%
advanced_data
# Out:
#      player_id  Unnamed: 0   Rk                              Player Pos  Age  \
# 0    adamsst01           0    1              Steven Adams\adamsst01   C   26
# 1    adebaba01           1    2               Bam Adebayo\adebaba01  PF   22
# 2    aldrila01           2    3         LaMarcus Aldridge\aldrila01   C   34
# 3    alexani01           3    4  Nickeil Alexander-Walker\alexani01  SG   21
# 4    allengr01           4    5             Grayson Allen\allengr01  SG   24
# ..         ...         ...  ...                                 ...  ..  ...
# 583  youngth01         583  502            Thaddeus Young\youngth01  PF   31
# 584  youngtr01         584  503                Trae Young\youngtr01  PG   21
# 585  zelleco01         585  504               Cody Zeller\zelleco01   C   27
# 586  zizican01         586  505                Ante Žižić\zizican01   C   23
# 587  zubaciv01         587  506               Ivica Zubac\zubaciv01   C   22
#
# ...

# %%
advanced_data.drop(columns=['Unnamed: 0','Rk','Tm',])

# %%
advanced_data.columns
# Out:
# Index(['player_id', 'Unnamed: 0', 'Rk', 'Player', 'Pos', 'Age', 'Tm', 'G',
#        'MP', 'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%',
#        'STL%', 'BLK%', 'TOV%', 'USG%', 'Unnamed: 19', 'OWS', 'DWS', 'WS',
#        'WS/48', 'Unnamed: 24', 'OBPM', 'DBPM', 'BPM', 'VORP'],
#       dtype='object')

# %%
adv_id = advanced_data['player_id']
advanced_data.drop(labels=['player_id'], axis=1,inplace = True)
advanced_data.insert(0, 'player_id', id)
advanced_data
# Out:
#      player_id  Unnamed: 0   Rk                              Player Pos  Age  \
# 0    vanvlfr01           0    1              Steven Adams\adamsst01   C   26
# 1    anunoog01           1    2               Bam Adebayo\adebaba01  PF   22
# 2    lowryky01           2    3         LaMarcus Aldridge\aldrila01   C   34
# 3    siakapa01           3    4  Nickeil Alexander-Walker\alexani01  SG   21
# 4    ibakase01           4    5             Grayson Allen\allengr01  SG   24
# ..         ...         ...  ...                                 ...  ..  ...
# 583        NaN         583  502            Thaddeus Young\youngth01  PF   31
# 584        NaN         584  503                Trae Young\youngtr01  PG   21
# 585        NaN         585  504               Cody Zeller\zelleco01   C   27
# 586        NaN         586  505                Ante Žižić\zizican01   C   23
# 587        NaN         587  506               Ivica Zubac\zubaciv01   C   22
#
# ...
